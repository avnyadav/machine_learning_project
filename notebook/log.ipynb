# %%
import pandas as pd

# %%
f="/home/avnish/iNeuron_Private_Intelligence_Limited/MachineLearningProject/machine_learning_project/logs/log_2022-07-06-19-40-36.log"

# %%
# Out:
#                     Time stamp Log Level line number         file name  \
# 0    [2022-07-06 19:40:36,738]      INFO         226  configuration.py
# 1    [2022-07-06 19:40:36,743]      INFO         224      _internal.py
# 2    [2022-07-06 19:40:42,739]      INFO         224      _internal.py
# 3    [2022-07-06 19:40:45,899]      INFO         224      _internal.py
# 4    [2022-07-06 19:40:50,204]      INFO         226  configuration.py
# ..                         ...       ...         ...               ...
# 134  [2022-07-06 19:40:55,171]      INFO          38   model_pusher.py
# 135  [2022-07-06 19:40:55,171]      INFO          50   model_pusher.py
# 136  [2022-07-06 19:40:55,171]      INFO         149       pipeline.py
# 137  [2022-07-06 19:40:55,171]      INFO         152       pipeline.py
# 138  [2022-07-06 19:40:55,171]      INFO         166       pipeline.py
#
#                       function name  \
# 0    get_training_pipeline_config()
# 1                            _log()
# 2                            _log()
# 3                            _log()
# 4    get_training_pipeline_config()
# ..                              ...
# 134                  export_model()
# 135                       __del__()
# 136                  run_pipeline()
# 137                  run_pipeline()
# 138                  run_pipeline()
#
#                                                message
# 0    Training pipleine config: TrainingPipelineConf...
# 1     * Running on http://127.0.0.1:5000 (Press CTR...
# 2    127.0.0.1 - - [06/Jul/2022 19:40:42] "GET / HT...
# 3    127.0.0.1 - - [06/Jul/2022 19:40:45] "GET /vie...
# 4    Training pipleine config: TrainingPipelineConf...
# ..                                                 ...
# 134  Model pusher artifact: [ModelPusherArtifact(is...
# 135  >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Model ...
# 136  Model pusher artifact: ModelPusherArtifact(is_...
# 137                              Pipeline completed.\n
# 138  Pipeline experiment: Experiment(experiment_id=...
#
# [139 rows x 6 columns]

# %%
df=pd.DataFrame(data)

# %%
df.columns=columns
